# %%
# !sudo service mysql start
# Out:
#  * Starting MySQL database server mysqld
# su: warning: cannot change directory to /nonexistent: No such file or directory
# /opt/conda/bin/xz
#    ...done.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="admin"
)

mycursor = mydb.cursor()

#mycursor.execute("CREATE DATABASE test")

# %% [markdown]
# CREATE DATABASE Northwind_DB;
# ("DROP DATABASE IF EXISTS CustomerDB")
#
# CREATE TABLE Customers (
#     CustomerID INT,
#     CustomerName VARCHAR(255),
#     ContactName VARCHAR(255),
#     Address VARCHAR(255),
#     City VARCHAR(255),
#     PostalCode VARCHAR(10),
#     Country VARCHAR(50)
# );

# %%
# Drop the database if it exists
mycursor.execute("DROP DATABASE IF EXISTS Northwind_DB")

# Create the database
mycursor.execute("CREATE DATABASE Northwind_DB")

print("Database created successfully!")
# Out:
# Database created successfully!

# %%
#mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")
for x in mycursor:
  print(x)
# Out:
# ('Northwind_DB',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('test',)
# ('w3schools_database',)

# %%
# Example -  connecting to the database "mydatabase":

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="admin",
  database="Northwind_DB" # Make sure the database is selected
)

mycursor = mydb.cursor()

# %% [markdown]
# CREATE TABLE Customers (
#     CustomerID INT,
#     CustomerName VARCHAR(255),
#     ContactName VARCHAR(255),
#     Address VARCHAR(255),
#     City VARCHAR(255),
#     PostalCode VARCHAR(10),
#     Country VARCHAR(50)
# );

# %%
mycursor = mydb.cursor()

mycursor.execute("""
CREATE TABLE Customers (
    CustomerID INT,
    CustomerName VARCHAR(255),
    ContactName VARCHAR(255),
    Address VARCHAR(255),
    City VARCHAR(255),
    PostalCode VARCHAR(10),
    Country VARCHAR(50)
)
""")

# %% [markdown]
# INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico'),
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico'),
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden');

# %%
sql = "INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (%s, %s, %s, %s, %s, %s, %s)"
val = [
    (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
    (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico'),
    (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico'),
    (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
    (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
]

mycursor.executemany(sql, val)
mydb.commit()

print(mycursor.rowcount, "records inserted.")
# Out:
# 5 records inserted.

# %% [markdown]
# SELECT CustomerName, City FROM Customers;

# %%
# Drop the database if it exists
mycursor.execute("DROP DATABASE IF EXISTS Northwind_DB")

# %%
import mysql.connector
from mysql.connector import Error

def execute_query(query, params=None):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch the results
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                return results
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# Example usage:
# For SELECT queries
select_query = "SELECT CustomerName, City FROM Customers"
results = execute_query(select_query)
for row in results:
    print(row)


# For INSERT, UPDATE, DELETE queries
insert_query = """
INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""
params = (6, 'New Customer', 'John Doe', '123 New St', 'New City', '12345', 'New Country')
rows_affected = execute_query(insert_query, params)
print(f"{rows_affected} record(s) inserted.")

# %%
import mysql.connector
from mysql.connector import Error

def execute_query(query, params=None):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and print the results
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                for row in results:
                    print(row)
                return results
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# %%
# Example usage:
# For SELECT queries
select_query = "SELECT CustomerName, City FROM Customers"
execute_query(select_query)
# Out:
# ('Alfreds Futterkiste', 'Berlin')
# ('Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Antonio Moreno Taquería', 'México D.F.')
# ('Around the Horn', 'London')
# ('Berglunds snabbköp', 'Luleå')
# [('Alfreds Futterkiste', 'Berlin'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.'),
#  ('Antonio Moreno Taquería', 'México D.F.'),
#  ('Around the Horn', 'London'),
#  ('Berglunds snabbköp', 'Luleå')]

# %%
# For INSERT, UPDATE, DELETE queries
insert_query = """
INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""
params = (6, 'New Customer', 'John Doe', '123 New St', 'New City', '12345', 'New Country')
rows_affected = execute_query(insert_query, params)
print(f"{rows_affected} record(s) inserted.")
# Out:
# 1 record(s) inserted.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

def execute_query(query, params=None):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and return the results as a DataFrame
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                df = pd.DataFrame(results, columns=[desc[0] for desc in cursor.description])
                for row in results:
                    #print(row)
                    pass
                return df
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# Example usage:
# For SELECT queries
select_query = "SELECT CustomerName, City FROM Customers"
df_results = execute_query(select_query)
display(df_results)

# For INSERT, UPDATE, DELETE queries
insert_query = """
INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""
params = (7, 'Another Customer', 'John Doe', '123 New St', 'New City', '12345', 'New Country')
rows_affected = execute_query(insert_query, params)
print(f"{rows_affected} record(s) inserted.")
# Out:
#                          CustomerName         City
# 0                 Alfreds Futterkiste       Berlin
# 1  Ana Trujillo Emparedados y helados  México D.F.
# 2             Antonio Moreno Taquería  México D.F.
# 3                     Around the Horn       London
# 4                  Berglunds snabbköp        Luleå
# 5                        New Customer     New City
# 6                    Another Customer     New City
# 7                    Another Customer     New City
# 1 record(s) inserted.

# %%
# Example usage:
# For SELECT queries
select_query = "SELECT CustomerName,Address,City,PostalCode,Country FROM Customers"
df_results = execute_query(select_query)
display(df_results)
# Out:
#                          CustomerName                        Address  \
# 0                 Alfreds Futterkiste                  Obere Str. 57
# 1  Ana Trujillo Emparedados y helados  Avda. de la Constitución 2222
# 2             Antonio Moreno Taquería                 Mataderos 2312
# 3                     Around the Horn                120 Hanover Sq.
# 4                  Berglunds snabbköp                 Berguvsvägen 8
# 5                        New Customer                     123 New St
# 6                    Another Customer                     123 New St
# 7                    Another Customer                     123 New St
# 8                    Another Customer                     123 New St
#
#           City PostalCode      Country
# 0       Berlin      12209      Germany
# 1  México D.F.      05021       Mexico
# 2  México D.F.      05023       Mexico
# 3       London    WA1 1DP           UK
# 4        Luleå   S-958 22       Sweden
# ...

# %% [markdown]
# SELECT DISTINCT Country FROM Customers;

# %%
# For SELECT DISTINCT queries
select_query = "SELECT DISTINCT City, Country FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#           City      Country
# 0       Berlin      Germany
# 1  México D.F.       Mexico
# 2       London           UK
# 3        Luleå       Sweden
# 4     New City  New Country

# %%
# For SELECT without DISTINCT queries
select_query = "SELECT Country FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#        Country
# 0      Germany
# 1       Mexico
# 2       Mexico
# 3           UK
# 4       Sweden
# 5  New Country
# 6  New Country
# 7  New Country
# 8  New Country

# %%
# SELECT COUNT(DISTINCT Country) FROM Customers;

select_query = "SELECT COUNT(*) FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    COUNT(*)
# 0         9

# %%
select_query = "SELECT COUNT(Country) FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    COUNT(Country)
# 0               9

# %%
select_query = "SELECT COUNT(DISTINCT Country) FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    COUNT(DISTINCT Country)
# 0                        5

# %%
select_query = "SELECT COUNT(DISTINCT Country) FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    COUNT(DISTINCT Country)
# 0                        5

# %%
select_query = "SELECT COUNT(DISTINCT Country) as Num_Countries FROM Customers;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    Num_Countries
# 0              5

# %% [markdown]
# SELECT Count(*) AS DistinctCountries
# FROM (SELECT DISTINCT Country FROM Customers);

# %%
select_query = "SELECT Count(*) AS DistinctCities FROM (SELECT DISTINCT City FROM Customers);"
df_results = execute_query(select_query)
display(df_results)
# Out:
# Error: 1248 (42000): Every derived table must have its own alias
# None

# %% [markdown]
# SELECT * FROM Customers
# WHERE Country='Mexico';

# %%
select_query = "SELECT * FROM Customers WHERE Country='Mexico';"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    CustomerID                        CustomerName     ContactName  \
# 0           2  Ana Trujillo Emparedados y helados    Ana Trujillo
# 1           3             Antonio Moreno Taquería  Antonio Moreno
#
#                          Address         City PostalCode Country
# 0  Avda. de la Constitución 2222  México D.F.      05021  Mexico
# 1                 Mataderos 2312  México D.F.      05023  Mexico

# %% [markdown]
# SELECT * FROM Customers
# WHERE CustomerID=1;

# %%
select_query = "SELECT * FROM Customers WHERE CustomerID=1;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    CustomerID         CustomerName   ContactName        Address    City  \
# 0           1  Alfreds Futterkiste  Maria Anders  Obere Str. 57  Berlin
#
#   PostalCode  Country
# 0      12209  Germany

# %%
# Create the Products table
create_table_query = """
CREATE TABLE Products (
    ProductID INT,
    ProductName VARCHAR(255),
    SupplierID INT,
    CategoryID INT,
    Unit VARCHAR(255),
    Price DECIMAL(10, 2)
)
"""
execute_query(create_table_query)
# Out:
# 0

# %%
# Insert data into the Products table
insert_data_query = """
INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (%s, %s, %s, %s, %s, %s)
"""
products_data = [
    (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.00),
    (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.00),
    (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.00),
    (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.00),
    (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
]
execute_query(insert_data_query, products_data)

print("Products table created and data inserted successfully.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[32], line 12
#       2 insert_data_query = """
#       3 INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (%s, %s, %s, %s, %s, %s)
#       4 """
#       5 products_data = [
#       6     (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.00),
#       7     (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.00),
#    (...)
#      10     (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
#      11 ]
# ---> 12 execute_query(insert_data_query, products_data)
#      14 print("Products table created and data inserted successfully.")
#
# Cell In[19], line 17, in execute_query(query, params)
#      15 if connection.is_connected():
#      16     cursor = connection.cursor()
# ---> 17     cursor.execute(query, params)
# ...

# %%
import mysql.connector
from mysql.connector import Error

def execute_query(query, params=None):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and return the results as a DataFrame
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                for row in results:
                    print(row)
                return results
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# Create the Products table
create_table_query = """
CREATE TABLE IF NOT EXISTS Products (
    ProductID INT,
    ProductName VARCHAR(255),
    SupplierID INT,
    CategoryID INT,
    Unit VARCHAR(255),
    Price DECIMAL(10, 2)
)
"""
execute_query(create_table_query)

# Insert data into the Products table
insert_data_query = """
INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (%s, %s, %s, %s, %s, %s)
"""
products_data = [
    (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.00),
    (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.00),
    (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.00),
    (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.00),
    (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
]
execute_query(insert_data_query, products_data)

print("Products table created and data inserted successfully.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[34], line 60
#      50 insert_data_query = """
#      51 INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (%s, %s, %s, %s, %s, %s)
#      52 """
#      53 products_data = [
#      54     (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.00),
#      55     (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.00),
#    (...)
#      58     (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
#      59 ]
# ---> 60 execute_query(insert_data_query, products_data)
#      62 print("Products table created and data inserted successfully.")
#
# Cell In[34], line 16, in execute_query(query, params)
#      14 if connection.is_connected():
#      15     cursor = connection.cursor()
# ---> 16     cursor.execute(query, params)
# ...

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

def execute_query(query, params=None, many=False):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            if many:
                cursor.executemany(query, params)
            else:
                cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and return the results as a DataFrame
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                df = pd.DataFrame(results, columns=[desc[0] for desc in cursor.description])
                for row in results:
                    print(row)
                return df
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# Create the Products table
create_table_query = """
CREATE TABLE IF NOT EXISTS Products (
    ProductID INT,
    ProductName VARCHAR(255),
    SupplierID INT,
    CategoryID INT,
    Unit VARCHAR(255),
    Price DECIMAL(10, 2)
)
"""
execute_query(create_table_query)

# Insert data into the Products table
insert_data_query = """
INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (%s, %s, %s, %s, %s, %s)
"""
products_data = [
    (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.00),
    (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.00),
    (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.00),
    (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.00),
    (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
]
execute_query(insert_data_query, products_data, many=True)

print("Products table created and data inserted successfully.")
# Out:
# Products table created and data inserted successfully.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="admin",
  database="Northwind_DB" # Make sure the database is selected
)

mycursor = mydb.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('Customers',)
# ('Products',)

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd


def execute_query(query, params=None, many=False):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            if many:
                cursor.executemany(query, params)
            else:
                cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and return the results as a DataFrame
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                df = pd.DataFrame(results, columns=[desc[0] for desc in cursor.description])
                for row in results:
                    #print(row)
                    pass
                return df
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# %% [markdown]
# SELECT * FROM Products
# ORDER BY Price DESC;

# %%
select_query = "SELECT * FROM Products ORDER BY Price DESC;"
df_results = execute_query(select_query)
display(df_results)
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          4  Chef Anton's Cajun Seasoning           2           2
# 1          5        Chef Anton's Gumbo Mix           2           2
# 2          2                         Chang           1           1
# 3          1                         Chais           1           1
# 4          3                 Aniseed Syrup           1           2
#
#                   Unit  Price
# 0       48 - 6 oz jars  22.00
# 1             36 boxes  21.35
# 2   24 - 12 oz bottles  19.00
# 3   10 boxes x 20 bags  18.00
# 4  12 - 550 ml bottles  10.00

# %% [markdown]
# ### Views
# Definition: A `view` is a virtual table based on the result-set of an SQL statement. It contains rows and columns, just like a real table.
# Example:
#
# ```sql
# CREATE VIEW CustomerView AS
# SELECT CustomerName, City, Country
# FROM Customers;
# ```

# %%
# Create the CustomerView view
create_view_query = """
CREATE VIEW CustomerView AS
    SELECT CustomerName, City, Country
FROM Customers;
"""

execute_query(create_view_query)
print("CustomerView created successfully.")
# Out:
# CustomerView created successfully.

# %%
# Drop the CustomerView view
drop_view_query = "DROP VIEW IF EXISTS CustomerView;"
execute_query(drop_view_query)
print("CustomerView dropped successfully.")
# Out:
# CustomerView dropped successfully.

# %%
# Query to list all views
list_views_query = """
SELECT TABLE_NAME
FROM information_schema.VIEWS
WHERE TABLE_SCHEMA = 'Northwind_DB';
"""
df_views = execute_query(list_views_query)
print(df_views)
# Out:
#      TABLE_NAME
# 0  CustomerView

# %% [markdown]
# ## Functions
# Definition: A `function` is a stored program that you can pass parameters into and return a single value. Functions are used to encapsulate reusable logic.
#
# Example
#
# ```sql
# CREATE FUNCTION GetCustomerCount()
# RETURNS INT
# BEGIN
#     DECLARE customerCount INT;
#     SELECT COUNT(*) INTO customerCount FROM Customers;
#     RETURN customerCount;
# END;
#
# ```

# %%
# Create the CustomerView view
create_function_query = """
CREATE FUNCTION GetCustomerCount()
RETURNS INT
BEGIN
    DECLARE customerCount INT;
    SELECT COUNT(*) INTO customerCount FROM Customers;
    RETURN customerCount;
END;
"""

execute_query(create_function_query)
print("GetCustomerCount function created successfully.")
# Out:
# Error: 1418 (HY000): This function has none of DETERMINISTIC, NO SQL, or READS SQL DATA in its declaration and binary logging is enabled (you *might* want to use the less safe log_bin_trust_function_creators variable)
# GetCustomerCount function created successfully.

# %%
# Create the GetCustomerCount function
create_function_query = """
CREATE FUNCTION GetCustomerCount()
RETURNS INT
DETERMINISTIC
BEGIN
    DECLARE customerCount INT;
    SELECT COUNT(*) INTO customerCount FROM Customers;
    RETURN customerCount;
END;

"""
execute_query(create_function_query)

print("GetCustomerCount function created successfully.")
# Out:
# GetCustomerCount function created successfully.

# %% [markdown]
# Set the `log_bin_trust_function_creators variable to 1`: This allows you to create functions without the additional characteristics, but it is less safe. You can set this variable temporarily or permanently.
#
# - **Temporarily** (for the current session):
# ```sql
# SET GLOBAL log_bin_trust_function_creators = 1;
# ```
#
# - **Permanently** (by editing the MySQL configuration file): Add the following line to your MySQL configuration file (e.g., my.cnf or my.ini):
# ```sql
# [mysqld]
# log_bin_trust_function_creators = 1
# ```
# Then Restart mysql server

# %%
# Query to list all functions
list_functions_query = """
SELECT ROUTINE_NAME
FROM information_schema.ROUTINES
WHERE ROUTINE_TYPE = 'FUNCTION' AND ROUTINE_SCHEMA = 'Northwind_DB';
"""
df_functions = execute_query(list_functions_query)
print(df_functions)
# Out:
#        ROUTINE_NAME
# 0  GetCustomerCount

# %%
# Drop the GetCustomerCount function
drop_function_query = "DROP FUNCTION IF EXISTS GetCustomerCount;"
execute_query(drop_function_query)

print("GetCustomerCount function dropped successfully.")
# Out:
# GetCustomerCount function dropped successfully.

# %%
# Call the GetCustomerCount function
call_function_query = "SELECT GetCustomerCount();"
df_result = execute_query(call_function_query)
print(df_result)
# Out:
#    GetCustomerCount()
# 0                   9

# %%
# Execute the equivalent query without using a function
count_query = "SELECT COUNT(*) AS customerCount FROM Customers;"
df_result = execute_query(count_query)
print(df_result)
# Out:
#    customerCount
# 0              9

# %% [markdown]
# ## Procedures
# Definition: A `procedure` is a stored program that you can pass parameters into and can perform actions such as modifying data or returning multiple values.
# Example:
#
# ```SQL
# CREATE PROCEDURE AddCustomer(
#     IN p_CustomerName VARCHAR(255),
#     IN p_ContactName VARCHAR(255),
#     IN p_Address VARCHAR(255),
#     IN p_City VARCHAR(255),
#     IN p_PostalCode VARCHAR(10),
#     IN p_Country VARCHAR(50)
# )
# BEGIN
#     INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country)
#     VALUES (p_CustomerName, p_ContactName, p_Address, p_City, p_PostalCode, p_Country);
# END;
# ```

# %%
# Create the AddCustomer procedure
create_procedure_query = """
CREATE PROCEDURE AddCustomer(
    IN p_CustomerID INT,
    IN p_CustomerName VARCHAR(255),
    IN p_ContactName VARCHAR(255),
    IN p_Address VARCHAR(255),
    IN p_City VARCHAR(255),
    IN p_PostalCode VARCHAR(10),
    IN p_Country VARCHAR(50)
)
BEGIN
    INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
    VALUES (p_CustomerID, p_CustomerName, p_ContactName, p_Address, p_City, p_PostalCode, p_Country);
END;
"""
execute_query(create_procedure_query)

print("AddCustomer procedure created successfully.")
# Out:
# AddCustomer procedure created successfully.

# %%
# Drop the AddCustomer procedure
drop_procedure_query = "DROP PROCEDURE IF EXISTS AddCustomer;"
execute_query(drop_procedure_query)

print("AddCustomer procedure dropped successfully.")
# Out:
# AddCustomer procedure dropped successfully.

# %%
# Query to list all procedures
list_procedures_query = """
SELECT ROUTINE_NAME
FROM information_schema.ROUTINES
WHERE ROUTINE_TYPE = 'PROCEDURE' AND ROUTINE_SCHEMA = 'Northwind_DB';
"""
df_procedures = execute_query(list_procedures_query)
print(df_procedures)
# Out:
#   ROUTINE_NAME
# 0  AddCustomer

# %%
# Use the AddCustomer procedure to add a new customer
add_customer_query = """CALL AddCustomer(%s, %s, %s, %s, %s, %s, %s);"""
customer_data = (8, 'Thomas AWF', 'John Doe', '123 New St', 'New City', '12345', 'New Country')

execute_query(add_customer_query, customer_data)
print("New customer added successfully.")
# Out:
# New customer added successfully.

# %%
# Add customer without using procedure - INSERT
insert_query = """
INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country)
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""
params = (7, 'Inserted Customer', 'Jane Doe', '22 Rue des Lilas', 'Paris', '75000', 'France')
rows_affected = execute_query(insert_query, params)
print(f"{rows_affected} record(s) inserted.")
# Out:
# 1 record(s) inserted.

# %%
list_procedures_query = """
SELECT ROUTINE_TYPE, ROUTINE_NAME
FROM INFORMATION_SCHEMA.ROUTINES
WHERE ROUTINE_TYPE = 'PROCEDURE' AND  ROUTINE_SCHEMA = 'Northwind_DB';
"""
df_procedures = execute_query(list_procedures_query)
print(df_procedures)

#WHERE ROUTINE_SCHEMA = 'Northwind_DB';
#WHERE ROUTINE_TYPE = 'PROCEDURE';
# Out:
#   ROUTINE_TYPE ROUTINE_NAME
# 0    PROCEDURE  AddCustomer

# %%
list_procedures_query = """
SELECT  ROUTINE_SCHEMA, ROUTINE_NAME, ROUTINE_TYPE
FROM INFORMATION_SCHEMA.ROUTINES
WHERE ROUTINE_SCHEMA = 'Northwind_DB';
"""
df_procedures = execute_query(list_procedures_query)
display(df_procedures)
# Out:
#   ROUTINE_SCHEMA      ROUTINE_NAME ROUTINE_TYPE
# 0   Northwind_DB  GetCustomerCount     FUNCTION
# 1   Northwind_DB       AddCustomer    PROCEDURE

# %%
# Query to list tables
list_tables_query = """
SELECT TABLE_SCHEMA, TABLE_NAME, TABLE_TYPE, ROW_FORMAT, TABLE_ROWS
FROM information_schema.tables
WHERE table_schema = 'Northwind_DB'
ORDER BY table_name;
"""
df_tables = execute_query(list_tables_query)
df_tables
# Out:
#    TABLE_SCHEMA    TABLE_NAME  TABLE_TYPE ROW_FORMAT  TABLE_ROWS
# 0  Northwind_DB  CustomerView        VIEW       None         NaN
# 1  Northwind_DB     Customers  BASE TABLE    Dynamic        13.0
# 2  Northwind_DB      Products  BASE TABLE    Dynamic         5.0

# %%
# Query to list tables
list_tables_query = """
SELECT *
FROM information_schema.tables
WHERE table_schema = 'Northwind_DB'
ORDER BY table_name;
"""
df_tables = execute_query(list_tables_query)
df_tables
# Out:
#   TABLE_CATALOG  TABLE_SCHEMA    TABLE_NAME  TABLE_TYPE  ENGINE  VERSION  \
# 0           def  Northwind_DB  CustomerView        VIEW    None      NaN
# 1           def  Northwind_DB     Customers  BASE TABLE  InnoDB     10.0
# 2           def  Northwind_DB      Products  BASE TABLE  InnoDB     10.0
#
#   ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  DATA_LENGTH  ...  INDEX_LENGTH  \
# 0       None         NaN             NaN          NaN  ...           NaN
# 1    Dynamic        13.0          1260.0      16384.0  ...           0.0
# 2    Dynamic         5.0          3276.0      16384.0  ...           0.0
#
#    DATA_FREE  AUTO_INCREMENT         CREATE_TIME         UPDATE_TIME  \
# 0        NaN            None 2024-11-06 13:19:44                 NaT
# 1        0.0            None 2024-11-05 14:32:49 2024-11-06 13:48:08
# 2        0.0            None 2024-11-05 15:21:36                 NaT
#
#   CHECK_TIME     TABLE_COLLATION CHECKSUM CREATE_OPTIONS TABLE_COMMENT
# ...

# %%
list_procedures_query = """
SELECT *
FROM INFORMATION_SCHEMA.ROUTINES
WHERE ROUTINE_SCHEMA = 'Northwind_DB';
"""
df_procedures = execute_query(list_procedures_query)
display(df_procedures)
# Out:
#       SPECIFIC_NAME ROUTINE_CATALOG ROUTINE_SCHEMA      ROUTINE_NAME  \
# 0  GetCustomerCount             def   Northwind_DB  GetCustomerCount
# 1       AddCustomer             def   Northwind_DB       AddCustomer
#
#   ROUTINE_TYPE DATA_TYPE CHARACTER_MAXIMUM_LENGTH CHARACTER_OCTET_LENGTH  \
# 0     FUNCTION       int                     None                   None
# 1    PROCEDURE                               None                   None
#
#    NUMERIC_PRECISION  NUMERIC_SCALE  ... SQL_PATH SECURITY_TYPE  \
# 0               10.0            0.0  ...     None       DEFINER
# 1                NaN            NaN  ...     None       DEFINER
#
#               CREATED        LAST_ALTERED  \
# 0 2024-11-06 13:33:08 2024-11-06 13:33:08
# 1 2024-11-06 13:48:02 2024-11-06 13:48:02
#
#                                             SQL_MODE ROUTINE_COMMENT  \
# 0  {STRICT_TRANS_TABLES, NO_ZERO_DATE, NO_ENGINE_...
# 1  {STRICT_TRANS_TABLES, NO_ZERO_DATE, NO_ENGINE_...
#
# ...

# %%
query = "SELECT * FROM Customers;"
df_result = execute_query(query)
display(df_result)
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0          1.0                 Alfreds Futterkiste        Maria Anders
# 1          2.0  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2          3.0             Antonio Moreno Taquería      Antonio Moreno
# 3          4.0                     Around the Horn        Thomas Hardy
# 4          5.0                  Berglunds snabbköp  Christina Berglund
# 5          6.0                        New Customer            John Doe
# 6          7.0                    Another Customer            John Doe
# 7          7.0                    Another Customer            John Doe
# 8          7.0                    Another Customer            John Doe
# 9          NaN                        New Customer            John Doe
# 10         NaN                        New Customer            John Doe
# 11         NaN                          Thomas AWF            John Doe
# ...

# %%
query = "SELECT * FROM Products;"
df_result = execute_query(query)
display(df_result)
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                         Chais           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#                   Unit  Price
# 0   10 boxes x 20 bags  18.00
# 1   24 - 12 oz bottles  19.00
# 2  12 - 550 ml bottles  10.00
# 3       48 - 6 oz jars  22.00
# 4             36 boxes  21.35

# %% [markdown]
# ```Materialized View```
# Definition: A `materialized view` is a database object that contains the results of a query. Unlike a regular view, which is a virtual table, a materialized view stores the query result physically. This can improve performance for complex queries as the data is precomputed and stored.
#
# Example:
#
# ```SQL
# CREATE MATERIALIZED VIEW SalesSummary AS
# SELECT ProductID, SUM(Quantity) AS TotalQuantity, SUM(Price) AS TotalSales
# FROM Sales
# GROUP BY ProductID;
# ```

# %%
query = """
CREATE TABLE Sales (
    SaleID INT PRIMARY KEY,
    ProductID INT,
    Quantity INT,
    Price DECIMAL(10, 2),
    SaleDate DATE
);
"""
df_result = execute_query(query)
display(df_result)
# Out:
# 0

# %%
query = "SELECT * FROM Sales;"
df_result = execute_query(query)
display(df_result)
# Out:
# Empty DataFrame
# Columns: [SaleID, ProductID, Quantity, Price, SaleDate]
# Index: []

# %%
query = """
INSERT INTO Sales (SaleID, ProductID, Quantity, Price, SaleDate) 
VALUES 
    (1, 101, 10, 15.00, '2024-11-01'),
    (2, 102, 5, 25.00, '2024-11-02'),
    (3, 101, 7, 15.00, '2024-11-03'),
    (4, 103, 3, 30.00, '2024-11-04'),
    (5, 102, 2, 25.00, '2024-11-05'),
    (6, 104, 8, 20.00, '2024-11-06'),
    (7, 105, 12, 22.50, '2024-11-07'),
    (8, 101, 5, 15.00, '2024-11-08'),
    (9, 103, 10, 30.00, '2024-11-09'),
    (10, 102, 7, 25.00, '2024-11-10');
"""
df_result = execute_query(query)
display(df_result)
# Out:
# Error: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
# None

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

def execute_query(query, params=None, many=False):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="admin",
            database="Northwind_DB"
        )
        
        if connection.is_connected():
            cursor = connection.cursor()
            if many:
                cursor.executemany(query, params)
            else:
                cursor.execute(query, params)
            
            # If the query is a SELECT statement, fetch and return the results as a DataFrame
            if query.strip().upper().startswith("SELECT"):
                results = cursor.fetchall()
                df = pd.DataFrame(results, columns=[desc[0] for desc in cursor.description])
                for row in results:
                    #print(row)
                    pass
                return df

                display(df)
            else:
                # Commit the transaction for INSERT, UPDATE, DELETE queries
                connection.commit()
                return cursor.rowcount
        
    except Error as e:
        print(f"Error: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

# %%
# Data to insert
data_to_insert = [
    (1, 101, 10, 15.00, '2024-11-01'),
    (2, 102, 5, 25.00, '2024-11-02'),
    (3, 101, 7, 15.00, '2024-11-03'),
    (4, 103, 3, 30.00, '2024-11-04'),
    (5, 102, 2, 25.00, '2024-11-05'),
    (6, 104, 8, 20.00, '2024-11-06'),
    (7, 105, 12, 22.50, '2024-11-07'),
    (8, 101, 5, 15.00, '2024-11-08'),
    (9, 103, 10, 30.00, '2024-11-09'),
    (10, 102, 7, 25.00, '2024-11-10')
]

# Insert query
insert_query = """
INSERT INTO Sales (SaleID, ProductID, Quantity, Price, SaleDate) 
VALUES (%s, %s, %s, %s, %s);
"""

# Execute the query
rows_inserted = execute_query(insert_query, params=data_to_insert, many=True)
print(f"{rows_inserted} rows were inserted into the Sales table.")
# Out:
# Error: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
# None rows were inserted into the Sales table.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd
import time

def execute_query(query, params=None, many=False, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            # Connect to MySQL
            connection = mysql.connector.connect(
                host="localhost",
                user="root",
                password="admin",
                database="Northwind_DB"
            )
            
            if connection.is_connected():
                cursor = connection.cursor()
                if many:
                    cursor.executemany(query, params)
                else:
                    cursor.execute(query, params)
                
                # If the query is a SELECT statement, fetch and return the results as a DataFrame
                if query.strip().upper().startswith("SELECT"):
                    results = cursor.fetchall()
                    df = pd.DataFrame(results, columns=[desc[0] for desc in cursor.description])
                    return df
                else:
                    # Commit the transaction for INSERT, UPDATE, DELETE queries
                    connection.commit()
                    return cursor.rowcount
        
        except Error as e:
            print(f"Error: {e}")
            if "Lock wait timeout exceeded" in str(e):
                attempt += 1
                print(f"Retrying... ({attempt}/{retries})")
                time.sleep(5)  # Wait for 5 seconds before retrying
            else:
                break
        finally:
            if connection.is_connected():
                cursor.close()
                connection.close()
    return None

# Data to insert
data_to_insert = [
    (1, 101, 10, 15.00, '2024-11-01'),
    (2, 102, 5, 25.00, '2024-11-02'),
    (3, 101, 7, 15.00, '2024-11-03'),
    (4, 103, 3, 30.00, '2024-11-04'),
    (5, 102, 2, 25.00, '2024-11-05'),
    (6, 104, 8, 20.00, '2024-11-06'),
    (7, 105, 12, 22.50, '2024-11-07'),
    (8, 101, 5, 15.00, '2024-11-08'),
    (9, 103, 10, 30.00, '2024-11-09'),
    (10, 102, 7, 25.00, '2024-11-10')
]

# Insert query
insert_query = """
INSERT INTO Sales (SaleID, ProductID, Quantity, Price, SaleDate) 
VALUES (%s, %s, %s, %s, %s);
"""

# Execute the query
rows_inserted = execute_query(insert_query, params=data_to_insert, many=True)
if rows_inserted:
    print(f"{rows_inserted} rows were inserted into the Sales table.")
else:
    print("No rows were inserted into the Sales table.")
# Out:
# Error: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
# Retrying... (1/3)
# Error: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
# Retrying... (2/3)
# Error: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
# Retrying... (3/3)
# No rows were inserted into the Sales table.

# %%
# Query to list tables
list_tables_query = """
SELECT *
FROM information_schema.tables
WHERE table_schema = 'Northwind_DB'
ORDER BY table_name;
"""
df_tables = execute_query(list_tables_query)
df_tables
# Out:
#   TABLE_CATALOG  TABLE_SCHEMA    TABLE_NAME  TABLE_TYPE  ENGINE  VERSION  \
# 0           def  Northwind_DB  CustomerView        VIEW    None      NaN
# 1           def  Northwind_DB     Customers  BASE TABLE  InnoDB     10.0
# 2           def  Northwind_DB      Products  BASE TABLE  InnoDB     10.0
# 3           def  Northwind_DB         Sales  BASE TABLE  InnoDB     10.0
#
#   ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  DATA_LENGTH  ...  INDEX_LENGTH  \
# 0       None         NaN             NaN          NaN  ...           NaN
# 1    Dynamic        14.0          1170.0      16384.0  ...           0.0
# 2    Dynamic         5.0          3276.0      16384.0  ...           0.0
# 3    Dynamic         5.0          3276.0      16384.0  ...           0.0
#
#    DATA_FREE  AUTO_INCREMENT         CREATE_TIME         UPDATE_TIME  \
# 0        NaN            None 2024-11-06 13:19:44                 NaT
# 1        0.0            None 2024-11-05 14:32:49 2024-11-06 14:05:36
# ...

# %%
query = "SELECT * FROM Sales;"

execute_query(query)
# Out:
# Empty DataFrame
# Columns: [SaleID, ProductID, Quantity, Price, SaleDate]
# Index: []

# %%
query = "SHOW ENGINE INNODB STATUS;" 

#df_result = execute_query(query)
#display(df_result)
